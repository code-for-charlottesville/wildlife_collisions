# %%
import pandas as pd

# %%
df = pd.read_excel('patient-medical-records-2024.xlsx')

# %%
df.columns
# Out:
# Index(['admissions.case_year', 'admissions.hash', 'admissions.id', 'exams.age',
#        'exams.age_unit', 'exams.attitude', 'exams.bcs', 'exams.body',
#        'exams.cardiopulmonary', 'exams.cns', 'exams.comments',
#        'exams.dehydration', 'exams.examined_at', 'exams.examiner',
#        'exams.forelimb', 'exams.gastrointestinal', 'exams.head',
#        'exams.hindlimb', 'exams.integument', 'exams.mm_color',
#        'exams.mm_texture', 'exams.musculoskeletal', 'exams.nutrition',
#        'exams.sex', 'exams.temperature', 'exams.temperature_unit',
#        'exams.treatment', 'exams.type', 'exams.weight', 'exams.weight_unit',
#        'patient_locations.area', 'patient_locations.comments',
#        'patient_locations.enclosure', 'patient_locations.moved_in_at',
#        'patient_locations.where_holding', 'patients.address_found',
#        'patients.admitted_at', 'patients.admitted_by', 'patients.band',
#        'patients.carcass_saved', 'patients.care_by_rescuer',
#        'patients.city_found', 'patients.clinical_signs',
#        'patients.common_name', 'patients.county_found',
#        'patients.criminal_activity', 'patients.custom_field_1',
#        'patients.custom_field_2', 'patients.days_in_care',
#        'patients.diagnosis', 'patients.disposition',
#        'patients.disposition_county', 'patients.disposition_lat',
#        'patients.disposition_lng', 'patients.disposition_location',
#        'patients.disposition_subdivision', 'patients.dispositioned_at',
#        'patients.dispositioned_by', 'patients.found_at', 'patients.keywords',
#        'patients.lat_found', 'patients.lng_found', 'patients.microchip_number',
#        'patients.morph', 'patients.name', 'patients.notes_about_rescue',
#        'patients.reason_for_disposition', 'patients.reasons_for_admission',
#        'patients.reference_number', 'patients.release_type',
#        'patients.subdivision_found', 'patients.transfer_type',
#        'patients.transported_by', 'people.address', 'people.alt_phone',
#        'people.city', 'people.country', 'people.county', 'people.email',
#        'people.entity', 'people.first_name', 'people.is_member',
#        'people.is_volunteer', 'people.last_name', 'people.no_solicitations',
#        'people.notes', 'people.organization', 'people.phone',
#        'people.postal_code', 'people.subdivision', 'species.class',
#        'species.family', 'species.genus', 'species.order', 'species.species'],
#       dtype='object')

# %% [markdown]
# ## Drop Rows where there is no geolocation information

# %%
df[['patients.address_found', 'patients.county_found', 'patients.city_found']]
# Out:
#                                  patients.address_found patients.county_found  \
# 0                                           1179 SR-712               Loudoun
# 1                                     3250 Bust Head Rd              Fauquier
# 2                     Intersection of Greenway and Rt 7               Loudoun
# 3                                       109 Keverne Ct.             Frederick
# 4                                  21024 Fox Hollow Ln.               Loudoun
# ...                                                 ...                   ...
# 3312                             225 Sister Chipmunk Ln             Frederick
# 3313                                20333 Tanager Place               Loudoun
# 3314  Found on a walking trail behind Dockside Terra...               Fairfax
# 3315                                 297 Cedar Mtn. Ln.                Warren
# 3316                            4723 Benjamin Cross Ct.               Fairfax
#
#      patients.city_found
# 0             Upperville
# 1             The Plains
# 2               Leesburg
# 3          Stephens City
# 4               Leesburg
# ...                  ...
# 3312          Clearbrook
# 3313            Leesburg
# 3314            Sterling
# 3315         Front Royal
# 3316           Chantilly
#
# [3317 rows x 3 columns]

# %% [markdown]
# Some of the data in 'patients.address_found' is not useful for programatically determining lat long coordinates. We want to drop the rows where the address_found starts with a alphabetic character AND either lat_found or lng_found is null

# %%
# determine which rows have the 'patients.address_found' column starting with a non-numeric character 
# df[df['patients.address_found'].str[0].str.isnumeric() == True]
# Set the 'patients.address_found' column to null for these rows
df.loc[df['patients.address_found'].str[0].str.isnumeric() == False, 'patients.address_found'] = None

# %%
# Drop rows where all the following columns are empty: 'patients.address_found', 'patients.lat_found', 'patients.long_found'
df = df.dropna(subset=['patients.address_found', 'patients.lat_found', 'patients.lng_found'], how='all')

# %% [markdown]
# ## Convert Address to Geolocation
# For rows where we have an address but no lat or long info

# %%
df[['patients.address_found', 'patients.lat_found', 'patients.lng_found']]
# Out:
#                                  patients.address_found  patients.lat_found  \
# 0                                           1179 SR-712                 NaN
# 1                                     3250 Bust Head Rd                 NaN
# 2                     Intersection of Greenway and Rt 7                 NaN
# 3                                       109 Keverne Ct.                 NaN
# 4                                  21024 Fox Hollow Ln.                 NaN
# ...                                                 ...                 ...
# 3312                             225 Sister Chipmunk Ln                 NaN
# 3313                                20333 Tanager Place                 NaN
# 3314  Found on a walking trail behind Dockside Terra...           39.040332
# 3315                                 297 Cedar Mtn. Ln.                 NaN
# 3316                            4723 Benjamin Cross Ct.                 NaN
#
#       patients.lng_found
# 0                    NaN
# 1                    NaN
# 2                    NaN
# 3                    NaN
# 4                    NaN
# ...                  ...
# 3312                 NaN
# 3313                 NaN
# 3314          -77.354295
# 3315                 NaN
# 3316                 NaN
#
# [3311 rows x 3 columns]

# %%
# Drop rows where either lat_found or _lng_found is NaN
df = df.dropna(subset=['patients.lat_found', 'patients.lng_found'])

# %%
# Unchecked but general direction of code
import geopy
from geopy.geocoders import Nominatim

loc = Nominatim(user_agent="Geopy Library")
get_loc = loc.geocode(df['patients.address_found'])
print(get_loc.latitute, "\n")
print(get_loc.longitude)

# %%
df[p[]]

# %%
df[['patients.lat_found', 'patients.lng_found']]
# Out:
#       patients.lat_found  patients.lng_found
# 48             38.831823       -7.752172e+01
# 75             39.034220       -7.740088e+01
# 174            39.501650       -7.801266e+01
# 183            38.841123       -7.792664e+07
# 186            39.039670       -7.791998e+07
# ...                  ...                 ...
# 3243           39.165549       -7.818914e+01
# 3265           39.030428       -7.750816e+01
# 3272           39.040514       -7.742277e+01
# 3300           39.086555       -7.813949e+01
# 3314           39.040332       -7.735429e+01
#
# [122 rows x 2 columns]

# %% [markdown]
# ## Determine Which ones are Vehicle Collision Related
#
# * The patients.keyword column contains relevant information. Search for "HBV" (Hit by Vehicle).
# * The patients.diagnosis column also has relevant data - "HBV" and "HBV" as a string in long from text
# * the patient.reasons_for_admission column has relevent info: "HBV" among others

# %% [markdown]
# ### Keyword Column

# %%
# Find all rows in the patient.keywords column that contain the string "HBV" and examine the results
df[df['patients.keywords'].str.contains('HBV', regex=False, case=False, na=False)]['patients.keywords'].value_counts()
# Out:
# patients.keywords
# suspect HBV                                                152
# B - Baby, mother killed, mother HBV, orphan                 20
# B - Baby, orphan, mother HBV                                18
# B - Baby, mother HBV, small                                  9
# suspect HBV, mother killed, B - Baby, small                  8
# B - Baby, suspect HBV                                        7
# mother HBV, mother killed, orphan, B - Baby, small           6
# B - Baby, small, mother HBV, orphan                          5
# suspect HBV, B - Baby                                        4
# suspect HBV, finder negligence                               2
# trauma, suspect HBV                                          2
# mother HBV, B - Baby, orphan                                 2
# B - Baby, mother killed, mother HBV, orphan, dog attack      2
# suspect HBV, lead                                            2
# suspect HBV,  suspect cat attack                             1
# suspect HBV, URI                                             1
# B - Baby, mother HBV, mother killed, orphan                  1
# gunshot, suspect HBV                                         1
# suspect HBV, rabies suspect                                  1
# B - Baby, mother killed, dog attack, mother HBV, orphan      1
# HBV                                                          1
# grounded, trauma, suspect HBV                                1
# Name: count, dtype: int64

# %%
# Grab the indexes of the rows that contain the string "HBV" in the patient.keywords column
keyword_column_hbv = df[df['patients.keywords'].str.contains('HBV', regex=False, case=False, na=False)].index

# %% [markdown]
# ### Diagnosis Column

# %%
df['patients.diagnosis'].value_counts()
# Out:
# patients.diagnosis
# T - Unknown Trauma                       768
# D - Domestic animal attack               440
# B - Baby                                 411
# S - Non-infectious Disease               243
# H - Hit by Vehicle                       166
# M - Human non-intentional                158
# X - Invasive                             157
# I - Infectious Disease                   123
# A - Abduction                            119
# W - Window Strike                         83
# U - Unknown                               34
# K - Toxicity                              25
# P - Predator Attack                       22
# F - Monofilament line or fishing hook     15
# J - Intentional Human Attack               7
# N - Natural Event                          5
# D - Domestic animal attack, baby           1
# Name: count, dtype: int64

# %%
# Find all rows in the patient.diagnosis column that are equal to "H - Hit by Vehicle" and examine the results
df[df['patients.diagnosis'].str.contains('Vehicle', regex=False, case=False, na=False)]['patients.diagnosis'].value_counts()
# Out:
# patients.diagnosis
# H - Hit by Vehicle    166
# Name: count, dtype: int64

# %%
# Grab the indexes of the rows that contain the string "Vehicle" in the patient.diagnosis column
diagnosis_column_vehicle = df[df['patients.diagnosis'].str.contains('Vehicle', regex=False, case=False, na=False)].index

# %% [markdown]
# ### Reasons for Admission Column

# %%
df['patients.reasons_for_admission'].value_counts()
# Out:
# patients.reasons_for_admission
# Cat attack                                          85
# HBV                                                 50
# Dog attack                                          37
# Abandoned                                           34
# Orphaned                                            31
#                                                     ..
# Hit the barn wall, unable to fly after 2 hours       1
# Eyes swollen and crusted shut                        1
# found down on side in yard, suspected leg injury     1
# Injured leg, confirmed dog had cardinal in mouth     1
# hit by car, DOA                                      1
# Name: count, Length: 1812, dtype: int64

# %%
# Set up a regex pattern to match the string "vehicle" or "HBV" or "collision" in the patient.reasons_for_admission column
vehicle_collision_regex = "vehicle|HBV|collision"

df[df['patients.reasons_for_admission'].str.contains("vehicle|HBV", regex=True, case=False, na=False)]

# %%
reasons_for_admit_examination = df[df['patients.reasons_for_admission'].str.contains("road", regex=True, case=False, na=False)]

# %%
# df[df['patients.reasons_for_admission'].isin(vehicle_collision_strings)]
df_x = df[df['patients.reasons_for_admission'].str.contains("vehicle", regex=True, case=False, na=False)]

# Find the rows where the patients.reason_for_admission column contains one of the following strings from the list: "HBV", "Road", "Vehicle"
# reasons_for_admit_vehicle = df[df['patients.reasons_for_admission'].str.contains("Vehicle", regex=True, case=False, na=False)].index

# %%
# Regex pattern matching for if a string contains the following strings: "vehicle", "HBV"
df_x1 = df[df['patients.reasons_for_admission'].str.contains("vehicle|HBV", regex=True, case=False, na=False)]
